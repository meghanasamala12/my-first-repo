# %%
pip install dash
# Out:
# Requirement already satisfied: dash in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (3.2.0)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from dash) (2.2.5)
# Requirement already satisfied: Werkzeug<3.2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from dash) (2.2.3)
# Requirement already satisfied: plotly>=5.0.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from dash) (6.3.1)
# Requirement already satisfied: importlib-metadata in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from dash) (6.11.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from dash) (4.15.0)
# Requirement already satisfied: requests in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from dash) (2.32.5)
# Requirement already satisfied: retrying in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from dash) (1.4.2)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from dash) (66.1.1)
# Requirement already satisfied: Jinja2>=3.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from Flask<3.2,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from Flask<3.2,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from Flask<3.2,>=1.0.4->dash) (8.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from Werkzeug<3.2->dash) (3.0.3)
# Requirement already satisfied: narwhals>=1.15.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from plotly>=5.0.0->dash) (2.9.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from plotly>=5.0.0->dash) (25.0)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from importlib-metadata->dash) (3.18.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from requests->dash) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from requests->dash) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from requests->dash) (2025.10.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import threading
import time
from collections import deque
from kafka import KafkaConsumer
import dash
from dash import dcc, html
from dash.dependencies import Output, Input

# %%
# ----------------------------
# Kafka Consumer Setup
# ----------------------------
consumer = KafkaConsumer(
    'sensor-data',
    bootstrap_servers=['localhost:9092'],
    value_deserializer=lambda m: json.loads(m.decode('utf-8')),
    auto_offset_reset='latest',
    enable_auto_commit=True,
    group_id='dashboard-group'
)

# %%
# ----------------------------
# Store recent data in memory
# ----------------------------
max_len = 50  # keep last 50 points
temps, hums, times = deque(maxlen=max_len), deque(maxlen=max_len), deque(maxlen=max_len)

def consume_kafka():
    for msg in consumer:
        data = msg.value
        temps.append(data["temperature"])
        hums.append(data["humidity"])
        times.append(data["timestamp"])

# Run Kafka consumer in background thread
threading.Thread(target=consume_kafka, daemon=True).start()

# %%
# ----------------------------
# Dash App Setup
# ----------------------------
app = dash.Dash(__name__)
app.layout = html.Div(
    [
        html.H1("🌡️ Real-Time Sensor Dashboard", style={"textAlign": "center"}),
        dcc.Graph(id="live-graph", animate=True),
        dcc.Interval(id="update-interval", interval=2000, n_intervals=0),  # update every 2s
    ]
)

# %%
@app.callback(Output("live-graph", "figure"), [Input("update-interval", "n_intervals")])
def update_graph(n):
    import plotly.graph_objs as go

    return {
        "data": [
            go.Scatter(x=list(times), y=list(temps), name="Temperature (°C)", mode="lines+markers"),
            go.Scatter(x=list(times), y=list(hums), name="Humidity (%)", mode="lines+markers"),
        ],
        "layout": go.Layout(
            xaxis=dict(title="Timestamp"),
            yaxis=dict(title="Value"),
            title="Live Sensor Data Stream",
            showlegend=True,
            uirevision='constant'
        ),
    }

# %%
if __name__ == "__main__":
    print("🚀 Starting Dashboard at http://127.0.0.1:8050")
    app.run(debug=True)
# Out:
# 🚀 Starting Dashboard at http://127.0.0.1:8050
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
